# %%
import pandas as pd
from matplotlib import pyplot as plt
import sklearn.datasets
import numpy as np
from sklearn.metrics import accuracy_score as Accuracy
from matplotlib import pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import KFold

# %%
datadf = pd.read_csv("UnigramVectorModel.csv")
datadf = datadf.fillna(0)
X, Y = datadf.drop(columns = "<label>").values, datadf["<label>"].values

# %%
#random forest training with count vectors
acc = []
kf = KFold(n_splits = 10)
for trainIndex, testIndex in kf.split(X):
    trainX, testX, trainY, testY = X[trainIndex], X[testIndex], Y[trainIndex], Y[testIndex]
    rfc = RandomForestClassifier(n_estimators = 10)
    rfc.fit(trainX, trainY)
    predictions = rfc.predict(testX)
    acc.append(Accuracy(testY, predictions))

# %%
print("Average accuracy of predictions " + str(np.mean(acc)))
plt.ylabel('accuracy')
plt.xlabel('iteration')
plt.plot(acc, 'b--')
plt.show()
# Out:
# Average accuracy of predictions 0.8004999999999999

# %%
print(confusion_matrix(testY, predictions))
# Out:
# [[ 16  50]
#  [  9 125]]

# %%
print(classification_report(testY, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.64      0.24      0.35        66
#         good       0.71      0.93      0.81       134
#
#    micro avg       0.70      0.70      0.70       200
#    macro avg       0.68      0.59      0.58       200
# weighted avg       0.69      0.70      0.66       200

# %%
unigramdf = pd.read_csv("UniTFIDFModel.csv")
unigramdf = unigramdf.fillna(0)
X, Y = unigramdf.drop(columns = "<label>").values, unigramdf["<label>"].values

# %%
#random forest training with tfidf vectors
acc = []
kf = KFold(n_splits = 10)
for trainIndex, testIndex in kf.split(X):
    trainX, testX, trainY, testY = X[trainIndex], X[testIndex], Y[trainIndex], Y[testIndex]
    rfc = RandomForestClassifier(n_estimators = 10)
    rfc.fit(trainX, trainY)
    predictions = rfc.predict(testX)
    acc.append(Accuracy(testY, predictions))

# %%
print("Average accuracy of predictions " + str(np.mean(acc)))
plt.ylabel('accuracy')
plt.xlabel('iteration')
plt.plot(acc, 'b--')
plt.show()
# Out:
# Average accuracy of predictions 0.7939999999999999

# %%
print(confusion_matrix(testY, predictions))
# Out:
# [[ 21  45]
#  [ 13 121]]

# %%
print(classification_report(testY, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.62      0.32      0.42        66
#         good       0.73      0.90      0.81       134
#
#    micro avg       0.71      0.71      0.71       200
#    macro avg       0.67      0.61      0.61       200
# weighted avg       0.69      0.71      0.68       200

# %%
datadf = pd.read_csv("BigramModel.csv", low_memory = False)
datadf = datadf.fillna(0)
X, Y = datadf.drop(columns = "<label>").values, datadf["<label>"].values

# %%
#random forest training with bigram vectors
acc = []
kf = KFold(n_splits = 10)
for trainIndex, testIndex in kf.split(X):
    trainX, testX, trainY, testY = X[trainIndex], X[testIndex], Y[trainIndex], Y[testIndex]
    rfc = RandomForestClassifier(n_estimators = 10)
    rfc.fit(trainX, trainY)
    predictions = rfc.predict(testX)
    acc.append(Accuracy(testY, predictions))

# %%
print("Average accuracy of predictions " + str(np.mean(acc)))
plt.ylabel('accuracy')
plt.xlabel('iteration')
plt.plot(acc, 'b--')
plt.show()
# Out:
# Average accuracy of predictions 0.7955

# %%
print(confusion_matrix(testY, predictions))
# Out:
# [[ 11  55]
#  [  2 132]]

# %%
print(classification_report(testY, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.85      0.17      0.28        66
#         good       0.71      0.99      0.82       134
#
#    micro avg       0.71      0.71      0.71       200
#    macro avg       0.78      0.58      0.55       200
# weighted avg       0.75      0.71      0.64       200

# %%
datadf = pd.read_csv("BigramTFIDF_Vector_Model.csv", low_memory = False)
datadf = datadf.fillna(0)
X, Y = datadf.drop(columns = "<label>").values, datadf["<label>"].values

# %%
#random forest training with bigram tfidf vectors
acc = []
kf = KFold(n_splits = 10)
for trainIndex, testIndex in kf.split(X):
    trainX, testX, trainY, testY = X[trainIndex], X[testIndex], Y[trainIndex], Y[testIndex]
    rfc = RandomForestClassifier(n_estimators = 10)
    rfc.fit(trainX, trainY)
    predictions = rfc.predict(testX)
    acc.append(Accuracy(testY, predictions))

# %%
print("Average accuracy of predictions " + str(np.mean(acc)))
plt.ylabel('accuracy')
plt.xlabel('iteration')
plt.plot(acc, 'b--')
plt.show()
# Out:
# Average accuracy of predictions 0.783

# %%
print(confusion_matrix(testY, predictions))
# Out:
# [[ 17  49]
#  [  8 126]]

# %%
print(classification_report(testY, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.68      0.26      0.37        66
#         good       0.72      0.94      0.82       134
#
#    micro avg       0.71      0.71      0.71       200
#    macro avg       0.70      0.60      0.59       200
# weighted avg       0.71      0.71      0.67       200
