# %%
import pandas as pd
from matplotlib import pyplot as plt
import sklearn.datasets
import numpy as np
from sklearn.metrics import accuracy_score as Accuracy
from matplotlib import pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import KFold

# %%
datadf = pd.read_csv("UnigramVectorModel.csv")
datadf = datadf.fillna(0)
X, Y = datadf.drop(columns = "<label>").values, datadf["<label>"].values

# %%
#random forest training with count vectors
acc = []
kf = KFold(n_splits = 10)
for trainIndex, testIndex in kf.split(X):
    trainX, testX, trainY, testY = X[trainIndex], X[testIndex], Y[trainIndex], Y[testIndex]
    rfc = RandomForestClassifier(n_estimators = 10)
    rfc.fit(trainX, trainY)
    predictions = rfc.predict(testX)
    acc.append(Accuracy(testY, predictions))

# %%
print("Average accuracy of predictions " + str(np.mean(acc)))
plt.ylabel('accuracy')
plt.xlabel('iteration')
plt.plot(acc, 'b--')
plt.show()
# Out:
# Average accuracy of predictions 0.794

# %%
print(confusion_matrix(testY, predictions))
# Out:
# [[ 13  53]
#  [  4 130]]

# %%
print(classification_report(testY, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.76      0.20      0.31        66
#         good       0.71      0.97      0.82       134
#
#    micro avg       0.71      0.71      0.71       200
#    macro avg       0.74      0.58      0.57       200
# weighted avg       0.73      0.71      0.65       200

# %%
unigramdf = pd.read_csv("UniTFIDFModel.csv")
unigramdf = unigramdf.fillna(0)
X, Y = unigramdf.drop(columns = "<label>").values, unigramdf["<label>"].values

# %%
#random forest training with tfidf vectors
acc = []
kf = KFold(n_splits = 10)
for trainIndex, testIndex in kf.split(X):
    trainX, testX, trainY, testY = X[trainIndex], X[testIndex], Y[trainIndex], Y[testIndex]
    rfc = RandomForestClassifier(n_estimators = 10)
    rfc.fit(trainX, trainY)
    predictions = rfc.predict(testX)
    acc.append(Accuracy(testY, predictions))

# %%
print("Average accuracy of predictions " + str(np.mean(acc)))
plt.ylabel('accuracy')
plt.xlabel('iteration')
plt.plot(acc, 'b--')
plt.show()
# Out:
# Average accuracy of predictions 0.7935000000000001

# %%
print(confusion_matrix(testY, predictions))
# Out:
# [[ 22  44]
#  [  8 126]]

# %%
print(classification_report(testY, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.73      0.33      0.46        66
#         good       0.74      0.94      0.83       134
#
#    micro avg       0.74      0.74      0.74       200
#    macro avg       0.74      0.64      0.64       200
# weighted avg       0.74      0.74      0.71       200

# %%
datadf = pd.read_csv("BigramModel.csv", low_memory = False)
datadf = datadf.fillna(0)
X, Y = datadf.drop(columns = "<label>").values, datadf["<label>"].values

# %%
#random forest training with bigram vectors
acc = []
kf = KFold(n_splits = 10)
for trainIndex, testIndex in kf.split(X):
    trainX, testX, trainY, testY = X[trainIndex], X[testIndex], Y[trainIndex], Y[testIndex]
    rfc = RandomForestClassifier(n_estimators = 10)
    rfc.fit(trainX, trainY)
    predictions = rfc.predict(testX)
    acc.append(Accuracy(testY, predictions))

# %%
print("Average accuracy of predictions " + str(np.mean(acc)))
plt.ylabel('accuracy')
plt.xlabel('iteration')
plt.plot(acc, 'b--')
plt.show()
# Out:
# Average accuracy of predictions 0.7969999999999999

# %%
print(confusion_matrix(testY, predictions))
# Out:
# [[  8  58]
#  [  2 132]]

# %%
print(classification_report(testY, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.80      0.12      0.21        66
#         good       0.69      0.99      0.81       134
#
#    micro avg       0.70      0.70      0.70       200
#    macro avg       0.75      0.55      0.51       200
# weighted avg       0.73      0.70      0.62       200
