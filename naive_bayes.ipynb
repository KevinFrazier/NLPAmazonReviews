# %%
import pandas as pd
from matplotlib import pyplot as plt
import sklearn.datasets
import numpy as np
from sklearn.metrics import accuracy_score as Accuracy
from matplotlib import pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import KFold

# %%
datadf = pd.read_csv("UnigramVectorModel.csv")
datadf = datadf.fillna(0)
X, Y = datadf.drop(columns = "<label>").values, datadf["<label>"].values

# %%
#niave training with count vectors
acc = []
kf = KFold(n_splits = 10)
for trainIndex, testIndex in kf.split(X):
    trainX, testX, trainY, testY = X[trainIndex], X[testIndex], Y[trainIndex], Y[testIndex]
    nb = MultinomialNB()
    nb.fit(trainX, trainY)
    predictions = nb.predict(testX)
    acc.append(Accuracy(testY, predictions))

# %%
print("Average accuracy of predictions " + str(np.mean(acc)))
plt.ylabel('accuracy')
plt.xlabel('iteration')
plt.plot(acc, 'b--')
plt.show()
# Out:
# Average accuracy of predictions 0.827

# %%
print(confusion_matrix(testY, predictions))
# Out:
# [[ 25  41]
#  [  8 126]]

# %%
print(classification_report(testY, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.76      0.38      0.51        66
#         good       0.75      0.94      0.84       134
#
#    micro avg       0.76      0.76      0.76       200
#    macro avg       0.76      0.66      0.67       200
# weighted avg       0.76      0.76      0.73       200

# %%
unigramdf = pd.read_csv("UniTFIDFModel.csv")
unigramdf = unigramdf.fillna(0)
X, Y = unigramdf.drop(columns = "<label>").values, unigramdf["<label>"].values

# %%
#niave training with unigram tfIdf vectors
acc = []
kf = KFold(n_splits = 10)
for trainIndex, testIndex in kf.split(X):
    trainX, testX, trainY, testY = X[trainIndex], X[testIndex], Y[trainIndex], Y[testIndex]
    nb = MultinomialNB()
    nb.fit(trainX, trainY)
    predictions = nb.predict(testX)
    acc.append(Accuracy(testY, predictions))

# %%
print("Average accuracy of predictions " + str(np.mean(acc)))
plt.ylabel('accuracy')
plt.xlabel('iteration')
plt.plot(acc, 'b--')
plt.show()
# Out:
# Average accuracy of predictions 0.472

# %%
print(confusion_matrix(testY, predictions))
# Out:
# [[45 21]
#  [77 57]]

# %%
print(classification_report(testY, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.37      0.68      0.48        66
#         good       0.73      0.43      0.54       134
#
#    micro avg       0.51      0.51      0.51       200
#    macro avg       0.55      0.55      0.51       200
# weighted avg       0.61      0.51      0.52       200

# %%
datadf = pd.read_csv("BigramModel.csv", low_memory = False)
datadf = datadf.fillna(0)
X, Y = datadf.drop(columns = "<label>").values, datadf["<label>"].values
print(datadf.shape)
print(X.shape)
print(Y.shape)
# Out:
# (2000, 60029)
# (2000, 60028)
# (2000,)

# %%
#niave training with bigram vectors
acc = []
kf = KFold(n_splits = 10)
for trainIndex, testIndex in kf.split(X):
    trainX, testX, trainY, testY = X[trainIndex], X[testIndex], Y[trainIndex], Y[testIndex]
    nb = MultinomialNB()
    nb.fit(trainX, trainY)
    predictions = nb.predict(testX)
    acc.append(Accuracy(testY, predictions))

# %%
print("Average accuracy of predictions " + str(np.mean(acc)))
plt.ylabel('accuracy')
plt.xlabel('iteration')
plt.plot(acc, 'b--')
plt.show()
# Out:
# Average accuracy of predictions 0.799

# %%
print(confusion_matrix(testY, predictions))
# Out:
# [[ 35  31]
#  [ 16 118]]

# %%
print(classification_report(testY, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.69      0.53      0.60        66
#         good       0.79      0.88      0.83       134
#
#    micro avg       0.77      0.77      0.77       200
#    macro avg       0.74      0.71      0.72       200
# weighted avg       0.76      0.77      0.76       200

# %%
datadf = pd.read_csv("BigramTFIDF_Vector_Model.csv", low_memory = False)
datadf = datadf.fillna(0)
X, Y = datadf.drop(columns = "<label>").values, datadf["<label>"].values

# %%
#niave training with bigram tfidf vectors
acc = []
kf = KFold(n_splits = 10)
for trainIndex, testIndex in kf.split(X):
    trainX, testX, trainY, testY = X[trainIndex], X[testIndex], Y[trainIndex], Y[testIndex]
    nb = MultinomialNB()
    nb.fit(trainX, trainY)
    predictions = nb.predict(testX)
    acc.append(Accuracy(testY, predictions))

# %%
print("Average accuracy of predictions " + str(np.mean(acc)))
plt.ylabel('accuracy')
plt.xlabel('iteration')
plt.plot(acc, 'b--')
plt.show()
# Out:
# Average accuracy of predictions 0.8320000000000001

# %%
print(confusion_matrix(testY, predictions))
# Out:
# [[ 29  37]
#  [ 10 124]]

# %%
print(classification_report(testY, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.74      0.44      0.55        66
#         good       0.77      0.93      0.84       134
#
#    micro avg       0.77      0.77      0.77       200
#    macro avg       0.76      0.68      0.70       200
# weighted avg       0.76      0.77      0.75       200
